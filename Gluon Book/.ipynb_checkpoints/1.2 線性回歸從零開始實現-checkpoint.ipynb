# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf

# %%
num_inputs = 2
num_examples = 1000
true_w = [2.0, -3.4]
true_b = [4.2]
features = np.random.normal(scale=0.01, size=(num_examples, num_inputs))
labels = true_w[0] * features[:, 0] + true_w[1] * features[:, 1] + true_b
labels += np.random.normal(scale=0.01, size=labels.shape)

# %%
from IPython.display import set_matplotlib_formats
def set_figsize(figsize=(3.5, 2.5)):
    set_matplotlib_formats('retina')            # 高清
    plt.rcParams['figure.figsize'] = figsize    # 設置圖的尺寸
    
set_figsize(figsize=(6, 4))
plt.scatter(features[:, 1], labels, 1)
plt.show()

# %%
features
# Out:
# array([[ 0.00500541,  0.00949183],
#        [ 0.00329251, -0.00977732],
#        [ 0.00494814, -0.00109787],
#        ...,
#        [-0.00532657,  0.0016103 ],
#        [ 0.00937219, -0.01134435],
#        [ 0.01213916, -0.00505062]])

# %%
batch_size = 10
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        j = np.array(indices[i: min(i + batch_size, num_examples)])
        yield features.take(j, axis=0), labels.take(j, axis=0)

# %%
for X, y in data_iter(batch_size, features, labels):
    print(X, y)
    break
# Out:
# [[-0.00308882 -0.00103681]
#  [-0.00116997 -0.01062349]
#  [ 0.00526292 -0.01370907]
#  [ 0.00199506 -0.01077577]
#  [ 0.00275924  0.01387077]
#  [-0.0065049   0.01305335]
#  [-0.02478262  0.01474229]
#  [-0.00209674  0.0026561 ]
#  [-0.00653456 -0.00407147]
#  [-0.00474295  0.00696676]] [4.19351467 4.24644259 4.26854849 4.25132859 4.14745991 4.13503246
#  4.11469584 4.18730066 4.2048015  4.16543368]

# %%
w1 = tf.Variable([[1,2]])
w2 = tf.Variable([2])

w3 = tf.multiply(w1, w2)

with tf.Session() as sess:
    tf.global_variables_initializer().run()
#     print(sess.run(tf.gradients(w1 * w1, [w1])))
    w1 = tf.subtract(w1, 1)
    print(sess.run(w1))
#     print(sess.run(w1).shape)
#     print(sess.run(w2).shape)
#     print(sess.run(w3))
# Out:
# [[0 1]]

# %%
learning_rate = 0.03

w = tf.Variable(np.random.normal(scale=0.01, size=(num_inputs, 1)), dtype=tf.float32)
b = tf.Variable(np.zeros(shape=(1,)), dtype=tf.float32)

x = tf.placeholder(shape=(None, num_inputs), dtype=tf.float32)

y_hat = tf.add(tf.matmul(x, w), b)

y = tf.placeholder(shape=(None, 1), dtype=tf.float32)

loss = tf.pow(y-y_hat, 2) / 2

sgd_w = tf.divide(tf.reduce_sum(tf.multiply(learning_rate, tf.gradients(loss, [w]))), batch_size)
sgd_b = tf.divide(tf.reduce_sum(tf.multiply(learning_rate, tf.gradients(loss, [b]))), batch_size)

# %%
epochs = 3
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(1, epochs+1):
        for batch_x, batch_y, in data_iter(batch_size, features, labels):
            batch_y = batch_y.reshape(-1, 1)
            train_sgd_w, train_sgd_b = sess.run([sgd_w, sgd_b], feed_dict={x: batch_x, y: batch_y})
            w, b = tf.subtract(w, train_sgd_w), tf.subtract(b, train_sgd_b)
            
        print(sess.run(loss, feed_dict={x: batch_x, y: batch_y}).mean())
#             print(sess.run(tf.gradients(loss, [w]), feed_dict={x: batch_x, y: batch_y}))
#             w = tf.subtract(w, tf.divide(tf.multiply(learning_rate, tf.gradients(loss, [w])), batch_size))
#             b = tf.subtract(b, tf.divide(tf.multiply(learning_rate, tf.gradients(loss, [b])), batch_size))
    print(sess.run([w, b]))
# Out:
# 8.859149
# 8.936352
# 8.779576
# [array([[0.02463129],
#        [0.01401385]], dtype=float32), array([37.78207], dtype=float32)]
